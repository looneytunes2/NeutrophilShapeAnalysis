# %%
import numpy as np
import os
import pandas as pd
import time
import math
import re
from itertools import groupby
from operator import itemgetter
# package for io 
from aicsimageio.writers import OmeTiffWriter
from aicsimageio.readers import tiff_reader, OmeTiffReader


import itertools
from skimage import measure as skmeasure
import datetime
from CustomFunctions import shparam_mod

from skimage.morphology import disk
from skimage.filters import median, gaussian


# load in some stuff to speed up processing
# (following https://sedeh.github.io/python-pandas-multiprocessing-workaround.html)
import multiprocessing

def collect_results(result):
    """Uses apply_async's callback to setup up a separate Queue for each process.
    This will allow us to collect the results from different threads."""
    results.append(result)
    

def mygrouper(n, iterable):
    args = [iter(iterable)] * n
    return ([e for e in t if e != None] for t in itertools.zip_longest(*args))
    


def get_intensity_features(img, seg):
    features = {}
    input_seg = seg.copy()
    input_seg = (input_seg>0).astype(np.uint8)
    input_seg_lcc = skmeasure.label(input_seg)
    for mask, suffix in zip([input_seg, input_seg_lcc], ['', '_lcc']):
        values = img[mask>0].flatten()
        if values.size:
            features[f'intensity_mean{suffix}'] = values.mean()
            features[f'intensity_std{suffix}'] = values.std()
            features[f'intensity_1pct{suffix}'] = np.percentile(values, 1)
            features[f'intensity_99pct{suffix}'] = np.percentile(values, 99)
            features[f'intensity_max{suffix}'] = values.max()
            features[f'intensity_min{suffix}'] = values.min()
        else:
            features[f'intensity_mean{suffix}'] = np.nan
            features[f'intensity_std{suffix}'] = np.nan
            features[f'intensity_1pct{suffix}'] = np.nan
            features[f'intensity_99pct{suffix}'] = np.nan
            features[f'intensity_max{suffix}'] = np.nan
            features[f'intensity_min{suffix}'] = np.nan
    return features



def dist_f(a1, b1, c1, a2, b2, c2):

    d = ( a1 * a2 + b1 * b2 + c1 * c2 )
    e1 = math.sqrt( a1 * a1 + b1 * b1 + c1 * c1)
    e2 = math.sqrt( a2 * a2 + b2 * b2 + c2 * c2)
    d = d / (e1 * e2)
    A = math.degrees(math.acos(d))
    return A

# Function to find Angle
def angle_distance(a1, b1, c1, a2, b2, c2):
    a1,b1,c1 = [a1,b1,c1]/np.linalg.norm([a1,b1,c1])
    a2,b2,c2 = [a2,b2,c2]/np.linalg.norm([a2,b2,c2])
    d = ( a1 * a2 + b1 * b2 + c1 * c2 )
    e1 = math.sqrt( a1 * a1 + b1 * b1 + c1 * c1)
    e2 = math.sqrt( a2 * a2 + b2 * b2 + c2 * c2)
    d = d / (e1 * e2)
    A = math.degrees(math.acos(d))
    return A

# %%
############################# RUN TRACKMATE TRACKING ON SEGMENTED IMAGES ##################################

# %%
from CustomFunctions.track_functions import segment_caax_tracks_confocal_40x_fromsingle

#### get together all images on the NAS #########

ip = 0.3394 #um / pixel .2285
step = 0.7 # um

#### directory info
bigdir = '//10.158.28.37/ExpansionHomesA/avlnas/HL60 ParaNitroBlebbistatin/'
foldlist = ['20231113']
savedir = 'D:/Aaron/Data/HL60 ParaNitroBlebbistatin/Tracking_Images/'
    
####  TZYX shape of the image
imshape = (181,150,1024,1024)

for f in foldlist:
    ims = [o for o in os.listdir(bigdir+f+'/')]
    for i in ims:
        #make the savedir if it doesn't exist
        if not os.path.exists(savedir+i+'/'):
            os.makedirs(savedir+i+'/')
        #directory of all the slices for this movie
        imdir = bigdir+f+'/'+i+'/Default/'
        
        
        ##### automatically detect image size
#         #sort the list of images and get the last one
#         last = sorted([o for o in os.listdir(imdir) if o.endswith('tif')])[-1]
#         #get stats about acquisition
#         cc,pos,maxtime,maxslices = [x for x in re.findall('\d*', last) if len(x)>1]
#         maxtime = int(maxtime)+1
#         maxslices = int(maxslices)+1
#         #open that image to get x,y size
#         shape = tiff_reader.TiffReader(imdir+last).shape
        
        results = []
        if __name__ ==  '__main__':
        # use multiprocessing to perform segmentation and x,y,z determination
            pool = multiprocessing.Pool(processes=60)
            for t in range(imshape[0]):
                pool.apply_async(segment_caax_tracks_confocal_40x_fromsingle, args=(imdir,
                                                                                    imshape[-3:],
                                                                                    ip,
                                                                                    step,
                                                                                    t, ), 
                                 callback=collect_results)
            pool.close()
            pool.join()
            


        #organize the semented frames into a segmented stack
        segmented_img = np.zeros((imshape[0],
                                 results[0][3][-3],
                                 results[0][3][-2],
                                 results[0][3][-1]))
        for r in results:
            fr = r[2]
            segmented_img[fr,:,:,:] = r[1]    

        #covert to more compact data type
        segmented_img = segmented_img.astype(np.uint8)

        #save the segmented image
        OmeTiffWriter.save(segmented_img, savedir+i+'/'+i+'_segmented.ome.tiff', dim_order = "TZYX", overwrite_file=True)


        #save the skimage region props
        df = pd.DataFrame()
        for d in results:
            df = df.append(pd.DataFrame(d[0], columns = ['cell', 
                         'frame', 'z_min', 'y_min', 
                        'x_min','z_max', 'y_max', 'x_max',
                       'z', 'y', 'x', 'z_range',
                       'area', 'convex_area', 'extent',
                       'minor_axis_length', 'major_axis_length',
                        'intensity_avg', 'intensity_max', 'intensity_std']))
        df = df.sort_values(by = ['frame','cell'])
        df.to_csv(savedir+i+'/'+i+'_region_props.csv')
        
        print(f'Finished processing {i}')
# Out:
# Finished processing 20231113_488EGFP-CAAX_0.1percentDMSO_1
# Finished processing 20231113_488EGFP-CAAX_0.1percentDMSO_2
# Finished processing 20231113_488EGFP-CAAX_0.1percentDMSO_3
# Finished processing 20231113_488EGFP-CAAX_10uMParaNitroBleb_1
# Finished processing 20231113_488EGFP-CAAX_10uMParaNitroBleb_2
# Finished processing 20231113_488EGFP-CAAX_10uMParaNitroBleb_3

# %%
############### SEGMENT AND SAVE CELLS ################################

############## alignment by chemical gradient ###################

from scipy.spatial import KDTree, distance
from itertools import groupby
from operator import itemgetter
from scipy import interpolate
import re
from aicsimageio.readers.bioformats_reader import BioformatsReader

#import the cell segmentation and rotation function
# import sys
# # insert at 1, 0 is the script path (or '' in REPL)
# import_path = 'C:/Users/Aaron/Documents/PythonScripts/CustomFunctions'
# sys.path.insert(1, import_path)
from CustomFunctions.segment_cells2short import seg_confocal_40x_memonly_fromslices

from CustomFunctions.persistance_activity import get_pa, velocity_and_distance


# path to folder(s)
folder_fl = 'D:/Aaron/Data/HL60 ParaNitroBlebbistatin/Tracking_Images/'
filelist_fl = [f for f in os.listdir(folder_fl)]
savedir = 'D:/Aaron/Data/HL60 ParaNitroBlebbistatin/Processed_Data/'
#make the savedir if it doesn't exist
if not os.path.exists(savedir):
    os.makedirs(savedir)
raw_dir = '//10.158.28.37/ExpansionHomesA/avlnas/HL60 ParaNitroBlebbistatin/'

#parameters for segmentation
xy_buffer = 20 #pixels
z_buffer = 10 #pixels
xyres = 0.3394 #um / pixel 
zstep = 0.7 # um
interval = 10
intthresh = 120 #for the half shrunken images, determined by manually crossreferencing
imshape = (150,1024,1024)



# u = filelist_fl[0]


for u in filelist_fl:

    ################## align trackmate data with region props data ################
    rpcsv = [x for x in os.listdir(folder_fl + u) if x.endswith("region_props.csv")][0]
    rp = pd.read_csv(folder_fl + u + '/' + rpcsv, index_col = 0)
    tmcsv = [x for x in os.listdir(folder_fl + u) if x.endswith("TrackMateLog.csv")][0]
    tm = pd.read_csv(folder_fl + u+ '/' + tmcsv)
    #fix trackmate columns to get names right and units in microns
    tm['x'] = tm.POSITION_X*xyres
    tm['y'] = tm.POSITION_Y*xyres
    tm['z'] = tm.POSITION_Z*zstep
    #make kdtree and query with trackmate log
    kd = KDTree(rp[['frame','x','y','z']].to_numpy())
    dd, ii = kd.query(tm[['FRAME','x','y','z']])
    df_track = pd.concat([tm.drop(columns=['POSITION_X','POSITION_Y','POSITION_Z']), 
                        rp.iloc[ii].drop(columns=['frame','x','y','z', 'cell']).reset_index(drop=True)], axis=1)
    df_track = df_track.rename(columns={'TRACK_ID':'cell', 'FRAME':'frame'})
    #sort by cell and frame
    df_track = df_track.sort_values(['cell','frame'])



    #############find distance travelled##################
    longdistmatrix = distance.pdist(df_track[['x','y','z']])
    shortdistmatrix = distance.squareform(longdistmatrix)
    shortdistmatrix = np.array(shortdistmatrix)
    dist = pd.Series([], dtype = 'float64')
    for count, i in enumerate(shortdistmatrix):
        if count == 0:
            temp = pd.Series([0])
            dist = dist.append(temp, ignore_index=True)
        else:
            temp = pd.Series(shortdistmatrix[count,count-1])
            dist = dist.append(temp, ignore_index=True)
    df_track = df_track.reset_index(drop = True)
    df_track['dist'] = dist
#     #first rows that have super long distances from previous cell, so set them to 0
#     df_track.loc[df_track.groupby('cell').head(1).index,'dist'] = 0

    ############ replace unrealistic jumps in distance ##############
    for x in df_track[df_track.dist>4].index.values:
        df_track['dist'][x] = df_track.dist.mean()

    ############## find euclidean distance #############
    euclid = pd.DataFrame([])
    for i, cell in df_track.groupby('cell'):
        FL = cell.iloc[[0,-1]]
        euc_dist = distance.pdist(FL[['x','y','z']])
        euclid = euclid.append({'cell':cell.cell.iloc[0], 'euc_dist':euc_dist[0]}, ignore_index = True)
    cellsmorethan = euclid.loc[euclid['euc_dist']>10, 'cell']
    df_track = df_track[df_track.cell.isin(cellsmorethan)]

    #     ########remove "slow"/dead cells############
    #     #sum distances
    #     df_track_distsums = df_track.groupby('cell').sum()
    #     df_track_distsums = df_track_distsums.add_suffix('_sum').reset_index()

    #     #grab only cells with sums above a threshold distance
    #     cellsmorethan = df_track_distsums.loc[df_track_distsums['dist_sum']>5, 'cell']
    #     df_track = df_track[df_track.cell.isin(cellsmorethan)]


    ########remove edge cells############
    #only grab rows that aren't zero in z_min
    df_track = df_track.loc[df_track['x_min'] !=0 ]
    df_track = df_track.loc[df_track['y_min'] !=0 ]
    df_track = df_track.loc[df_track['z_min'] !=0 ]
    #remove rows where z_max matches z_range
    df_track = df_track.loc[df_track['x_max'] < imshape[-1]]
    df_track = df_track.loc[df_track['y_max'] < imshape[-2]]
    df_track = df_track.loc[df_track['z_max'] != (df_track['z_range'])]
    
    
    ##########remove small things that are likely dead cells or parts of cells###########
    df_track = df_track[df_track['area'] > 4000 ]


    #reset index after dropping all the rows
    df_track = df_track.reset_index(drop = True)



    ######## remove cells that touch ###########    
    to_remove = []
    for i, cell in df_track.groupby('cell'):
        if i>0:
            changes = abs(cell['convex_area'].pct_change())
            largerthan = changes[changes>0.75]
            if largerthan.empty == False:
                to_remove.extend(largerthan.index.to_list())


            # changes = cell['convex_area'].diff()
            # largerthan = changes[changes>cell['convex_area']*0.333]
            # smallerthan = changes[changes<cell['convex_area']*-0.333]
            # print(largerthan.index,smallerthan.index)
            # #remove all frames of a cell after it contacts another cell
            # if largerthan.empty == False:
            #     for n in largerthan.index:
            #         to_remove.append(list(range(n, max(cell.index)+1)))
            # #remove all frames of a cell before it splits from another cell
            # if smallerthan.empty == False:
            #     for n in smallerthan.index:
            #         to_remove.append(list(range(cell.index[0], n-1)))
    # #remove duplicate indicies
    # to_remove = [j for x in to_remove for j in x]
    # to_remove = list(set(to_remove))
    #drop touching or splitting cells
    df_track = df_track.drop(to_remove)



    if df_track.empty == False:
        for i, cells in df_track.groupby('cell'):
            cells = cells.reset_index(drop = True)
            runs = list()
            #######https://stackoverflow.com/questions/2361945/detecting-consecutive-integers-in-a-list
            for k, g in groupby(enumerate(cells['frame']), lambda ix: ix[0] - ix[1]):
                currentrun = list(map(itemgetter(1), g))
                list.append(runs, currentrun)
            for r in runs:
                r = np.array(r, dtype=int)
                #skip runs less than 3 frames long
                if len(r)<3:
                    pass
                else:
                    cell = cells.iloc[[cells[cells.frame==y].index[0] for y in r]]
                    #segment the cell channel and get centroid
                    df = pd.DataFrame()
                    if __name__ ==  '__main__':
                        # use multiprocessing to perform segmentation and x,y,z determination
                        pool = multiprocessing.Pool(processes=60)
                        results = []
                        for t, row in cell.iterrows():
                            
                            tdir = raw_dir +u.split('_')[0]+'/' +u+'/Default/'
                            
                            xmincrop = int(max(0, row.x_min-xy_buffer))
                            ymincrop = int(max(0, row.y_min-xy_buffer))
                            zmincrop = int(max(0, row.z_min-z_buffer))

                            zmaxcrop = int(min(row.z_max+z_buffer, imshape[-3]))
                            ymaxcrop = int(min(row.y_max+xy_buffer, imshape[-2])+1)
                            xmaxcrop = int(min(row.x_max+xy_buffer, imshape[-1])+1)
                            
                            pool.apply_async(seg_confocal_40x_memonly_fromslices, args = (
                                tdir,
                                imshape,
                                row,
                                u,
                                savedir,
                                xyres,
                                zstep,
                                xmincrop, 
                                ymincrop, 
                                zmincrop,
                                xmaxcrop, 
                                ymaxcrop, 
                                zmaxcrop,
                                ),             
                                callback = collect_results)

                        pool.close()
                        pool.join()

                        print(f'Done segmenting {u} cell {cell.cell.iloc[0]}')

                    if any([x == None for x in results]):
                        ind = results.index(None)
                        if len(results[:ind])<3:
                            pass
                        else:
                            results = results[:ind]

                    #aggregate the dataframe
                    for d in results:
                        df = df.append(pd.DataFrame(d, columns = d.keys(), index=[0]))
                    df = df.sort_values(by = 'frame').reset_index(drop=True)



                    #make sure there are no gaps due to failed segmentations
                    if any(df.frame.diff()>1):
                        dft = df.reset_index(drop = True)
                        runs = list()
                        #######https://stackoverflow.com/questions/2361945/detecting-consecutive-integers-in-a-list
                        for k, g in groupby(enumerate(dft['frame']), lambda ix: ix[0] - ix[1]):
                            currentrun = list(map(itemgetter(1), g))
                            list.append(runs, currentrun)
                        whichframes = np.array(max(runs, key=len), dtype=int)
                        pullrows = dft[dft.frame.isin(whichframes)]
                        df = pullrows.copy().reset_index(drop=True)


                    #add new distances from cropped image
                    #############find distance travelled##################
                    longdistmatrix = distance.pdist(df[['x','y','z']])
                    shortdistmatrix = distance.squareform(longdistmatrix)
                    shortdistmatrix = np.array(shortdistmatrix)
                    dist = pd.Series([], dtype = 'float64')
                    for count, i in enumerate(shortdistmatrix):
                        if count == 0:
                            tmp = pd.Series([0])
                            dist = dist.append(tmp, ignore_index=True)
                        else:
                            tmp = pd.Series(shortdistmatrix[count,count-1])
                            dist = dist.append(tmp, ignore_index=True)
                    df['dist'] = dist



                    ############## Bayesian persistence and activity #################
                    persistence, activity, speed = get_pa(df, interval)
                    df['persistence'] = np.concatenate([np.array([np.nan]*2), persistence])
                    df['activity'] = np.concatenate([np.array([np.nan]*2), activity])
                    df['speed'] = np.concatenate([np.array([np.nan]), speed])
                    df['avg_persistence'] = np.array([persistence.mean()]*(len(persistence)+2))
                    df['avg_activity'] = np.array([activity.mean()]*(len(activity)+2))
                    df['avg_speed'] = np.array([speed.mean()]*(len(speed)+1))


                    ################ Signal velocities and distance travelled ###############
                    isvs, sds, tds, eds = velocity_and_distance(df, interval, )
                    df['Instant_Signal_Velocity'] = np.concatenate([np.array([np.nan]), np.array(isvs)])
                    df['Signal_Velocity'] = np.concatenate([np.array([np.nan]), sds])
                    df['Total_Distance_Travelled'] = np.concatenate([np.array([np.nan]), tds])
                    df['Euclidean_Distance_Travelled'] = np.concatenate([np.array([np.nan]), eds])


                    #set the k order for interpolation to the max possible
                    if len(df)<6:
                        kay = len(df)-1
                    else:
                        kay = 5

                    #     seg_nucleus[t,:,:,:] = segment_nucleus(temp_im[t,1,:,:,:])
                    pos = df[['x','y','z']]
                    if bool(pos[pos.duplicated()].index.tolist()):
                        ######### FIND CELL TRAJECTORY AND EULER ANGLES ################
                        # if there is duplicate positions
                        dups = pos[pos.duplicated()].index.tolist()
                        pos_drop = pos.drop(dups, axis = 0)
                        if pos_drop.shape[0]<3:
                            traj = np.zeros([1,2,3])
                        else:
                            #get trajectories without the duplicates
                            tck, u = interpolate.splprep(pos_drop.to_numpy().T, k=kay, s=5)
                            yderv = interpolate.splev(u,tck,der=1)
                            traj = np.vstack(yderv).T
                            #re-insert duplicate row that was dropped
                            for d, dd in enumerate(dups):
                                traj = np.insert(traj, dd, traj[dd-1,:], axis=0)

                    else:
                        ######### FIND CELL TRAJECTORY AND EULER ANGLES ################
                        #no duplicate positions
                        #interpolate and get tangent at midpoint
                        tck, b = interpolate.splprep(pos.to_numpy().T, k=kay, s=5)
                        yderv = interpolate.splev(b,tck,der=1)
                        traj = np.vstack(yderv).T

                    #get the trajectory and the previous trajectory for each frame and 
                    #save as an individual dataframe for each cell and frame
                    for v, row in df.iterrows():
                        row = df.loc[v]
                        if v==0:
                            row['Prev_Trajectory_X'] = np.nan
                            row['Prev_Trajectory_Y'] = np.nan
                            row['Prev_Trajectory_Z'] = np.nan
                            row['Trajectory_X'] = traj[v,0]
                            row['Trajectory_Y'] = traj[v,1]
                            row['Trajectory_Z'] = traj[v,2]
                            row['Turn_Angle'] = np.nan
                            pd.DataFrame(row.to_dict(),index=[0]).to_csv(savedir + row.cell + '_cell_info.csv')
                        if v>0:
                            row['Prev_Trajectory_X'] = traj[v-1,0]
                            row['Prev_Trajectory_Y'] = traj[v-1,1]
                            row['Prev_Trajectory_Z'] = traj[v-1,2]
                            row['Trajectory_X'] = traj[v,0]
                            row['Trajectory_Y'] = traj[v,1]
                            row['Trajectory_Z'] = traj[v,2]
                            row['Turn_Angle'] = angle_distance(traj[v-1,0], traj[v-1,1], traj[v-1,2], traj[v,0], traj[v,1], traj[v,2])
                            pd.DataFrame(row.to_dict(),index=[0]).to_csv(savedir + row.cell + '_cell_info.csv')
# Out:
# C:\Users\Aaron\anaconda3\envs\abhishape\lib\site-packages\ipykernel_launcher.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 2
# C:\Users\Aaron\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py:1056: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cacher_needs_updating = self._check_is_chained_assignment_possible()
# C:\Users\Aaron\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:1724: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer_missing(indexer, value)
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 3
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 5
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 6
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 8
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 9
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 9
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 9
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 9
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 9
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 10
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 10
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 12
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 12
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 13
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 15
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 15
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 16
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 16
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 17
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 19
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 21
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 22
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 24
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 26
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 26
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 26
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 27
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 27
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 27
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 28
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 29
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 29
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 30
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 30
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 31
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 34
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 34
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 35
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 36
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 36
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 36
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 36
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 36
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 37
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 38
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 39
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 40
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 40
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 42
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 42
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 46
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 46
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 53
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 55
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 55
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 60
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 61
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 62
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 65
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 65
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 66
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 66
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 76
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 77
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_1 cell 77
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 0
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 0
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 0
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 0
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 0
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 0
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 1
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 2
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 2
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 3
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 4
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 8
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 8
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 8
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 8
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 9
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 10
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 10
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 10
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 10
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 10
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 11
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 13
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 14
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 15
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 17
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 17
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 18
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 19
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 21
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 21
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 24
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 27
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 30
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 31
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 31
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 31
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 35
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 36
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 39
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 40
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 42
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 43
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 46
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 50
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 61
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 64
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 64
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 64
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 64
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 78
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_2 cell 79
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 0
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 1
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 1
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 4
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 4
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 6
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 16
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 17
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 23
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 23
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 24
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 25
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 26
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 27
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 28
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 29
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 29
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 31
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 32
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 32
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 32
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 32
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 32
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 40
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 42
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 42
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 42
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 53
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 53
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 53
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 65
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 65
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 65
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 71
# Done segmenting 20231108_488EGFP-CAAX_0.1percentDMSO_4 cell 88
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 2
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 6
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 7
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 7
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 9
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 10
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 12
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 16
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 17
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 18
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 20
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 21
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 22
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 23
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 23
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 23
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 24
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 26
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 27
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 27
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 27
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 27
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 28
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 28
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 28
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 29
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 30
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 30
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 31
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 31
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 31
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 31
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 33
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 33
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 34
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 34
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 35
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 35
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 35
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 35
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 35
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 36
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 36
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 37
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 39
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 39
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 39
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 39
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 40
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 40
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 53
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 53
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 53
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 53
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 53
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 58
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 64
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 68
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 72
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 77
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 78
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 80
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 82
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 87
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_1 cell 87
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 0
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 1
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 2
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 2
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 4
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 5
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 5
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 7
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 7
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 12
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 12
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 12
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 13
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 13
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 15
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 16
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 17
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 19
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 20
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 21
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 23
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 24
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 24
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 26
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 27
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 28
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 29
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 32
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 33
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 35
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 37
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 38
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 38
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 38
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 42
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 51
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 51
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 51
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 66
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_2 cell 66
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 2
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 3
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 3
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 3
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 3
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 6
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 13
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 15
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 17
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 18
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 19
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 20
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 20
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 22
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 23
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 28
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 29
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 29
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 34
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 36
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 36
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 38
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 39
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 39
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 42
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 42
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 43
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 47
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 50
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 52
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 64
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 69
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 69
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 70
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 71
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 71
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 72
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 73
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 73
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 81
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 90
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 94
# Done segmenting 20231108_488EGFP-CAAX_10uMParaNitroBleb_3 cell 97
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 0
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 0
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 0
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 1
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 3
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 5
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 5
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 7
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 9
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 11
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 12
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 14
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 14
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 14
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 15
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 16
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 16
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 17
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 18
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 19
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 20
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 21
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 21
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 24
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 26
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 27
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 28
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 32
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 34
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 36
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 38
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 39
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 40
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 40
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 40
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 40
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 40
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 40
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 41
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 41
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 55
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 56
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 56
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 60
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 61
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 64
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_1 cell 72
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 1
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 2
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 3
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 4
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 4
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 5
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 5
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 6
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 9
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 9
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 9
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 10
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 10
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 11
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 11
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 12
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 12
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 14
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 14
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 14
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 14
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 14
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 14
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 15
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 16
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 17
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 18
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 20
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 20
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 20
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 22
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 23
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 23
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 25
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 27
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 29
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 29
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 41
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 42
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 43
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 50
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 52
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_2 cell 59
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 1
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 1
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 1
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 2
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 2
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 9
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 11
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 12
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 14
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 14
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 14
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 15
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 16
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 17
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 18
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 18
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 20
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 20
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 21
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 22
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 22
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 22
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 27
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 27
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 33
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 33
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 44
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 44
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 44
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 46
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 49
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 50
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 50
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 51
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 53
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 56
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 58
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 60
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 64
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 65
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 72
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 81
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 86
# Done segmenting 20231113_488EGFP-CAAX_0.1percentDMSO_3 cell 92
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 1
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 3
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 3
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 6
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 7
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 7
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 7
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 7
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 8
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 10
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 14
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 20
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 21
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 23
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 24
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 24
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 27
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 28
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 33
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 33
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 33
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 33
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 33
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 33
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_1 cell 35
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 0
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 4
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 8
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 8
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 8
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 9
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 10
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 10
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 11
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 11
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 13
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 14
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 14
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 14
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 16
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 16
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 18
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 19
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 19
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 19
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 21
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 21
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 21
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 24
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 24
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 24
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 24
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 24
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 29
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 29
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 30
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 33
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 37
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 37
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 37
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 40
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 45
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_2 cell 49
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 0
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 0
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 2
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 2
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 3
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 4
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 5
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 5
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 8
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 10
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 10
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 10
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 10
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 12
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 13
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 15
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 15
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 15
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 25
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 26
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 27
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 27
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 28
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 30
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 31
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 34
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 34
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 34
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 34
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 42
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 51
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 51
# Done segmenting 20231113_488EGFP-CAAX_10uMParaNitroBleb_3 cell 52

# %%
############ FIND WIDTH ROTATIONS THAT DEPEND ON PREVIOUS FRAMES TO LIMIT ROTATION FLIPPING ################

mindir = 'D:/Aaron/Data/HL60 ParaNitroBlebbistatin/'
savedir = mindir + 'Processed_Data/'
datadir = mindir + 'Data_and_Figs/'
if not os.path.exists(datadir):
    os.makedirs(datadir)

xyres = 0.3394 #um / pixel 
zstep = 0.7 # um
align_method = 'trajectory'
sigma = 0

imlist = []
for o in os.listdir(savedir):
    if 'segmented' in o:
        cellid = o.split('_frame')[0]
        if cellid not in imlist:
            imlist.append(cellid)
            
allresults = []
for i in imlist:
    if __name__ ==  '__main__':
        results = []
        pool = multiprocessing.Pool(processes=60)
        for j in os.listdir(savedir):
            if (i+'_' in j) and ('segmented' in j):
                #get path to segmented image
                impath = savedir + j
    
                #put in the pool
                pool.apply_async(shparam_mod.find_normal_width_peaks, args = (
                    impath,
                    xyres,
                    zstep,
                    sigma,
                    align_method,
                    ),             
                    callback = collect_results)
    
        pool.close()
        pool.join()
    
    results.sort(key=lambda x: float(re.findall('(?<=frame_)\d*', x[0])[0]))
    tempframe = pd.DataFrame(results, columns = ['cell','Width_Peaks'])
    tempframe['frame'] = [float(re.findall('(?<=frame_)\d*', x[0])[0]) for x in results]
    
    runs = list()
    #######https://stackoverflow.com/questions/2361945/detecting-consecutive-integers-in-a-list
    for k, g in groupby(enumerate(tempframe['frame']), lambda ix: ix[0] - ix[1]):
        currentrun = list(map(itemgetter(1), g))
        list.append(runs, currentrun)

    
    #find the minima in each frame that are closest to the minimum chosen in the last frame
    #aka the one that results in the least amount of consecutive rotation
    fullminlist = []
    for xx in runs:
        runframe = tempframe[tempframe.frame.isin(xx)]
        wplist = runframe.Width_Peaks.to_list()
        seeds = []
        allallmins = []
        #for all the starting peaks find the least different rotations through time
        for s in wplist[0]:
            allmins = [s]
            for wp in wplist[1:]:
                if bool(len(wp) == 0):
                    allmins.append(allmins[-1])
                else:
                    allmins.append(wp[np.argmin(abs(wp-(allmins[-1])))])
            allallmins.append(allmins)
            seeds.append(np.sum(abs(np.diff(allmins))))
        #add rotations of current run to the list
        fullminlist.extend(allallmins[np.argmin(seeds)])  
    
    
    #add all mins to tempframe
    tempframe['Closest_minimums'] = fullminlist
    
    allresults.append(tempframe)
    
    print('Finished '+ i)

#save the shape metrics dataframe
bigdf = pd.concat(allresults)
bigdf.to_csv(datadir + 'Closest_Width_Peaks.csv')
# Out:
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_10
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_12
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_13
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_15
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_16
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_17
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_19
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_21
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_22
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_24
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_26
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_27
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_28
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_29
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_2
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_30
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_31
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_34
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_35
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_36
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_37
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_38
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_39
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_3
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_40
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_42
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_46
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_53
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_55
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_5
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_60
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_61
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_62
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_65
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_66
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_6
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_76
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_77
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_8
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_9
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_0
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_10
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_11
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_13
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_14
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_15
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_17
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_18
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_19
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_1
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_21
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_24
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_27
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_2
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_30
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_31
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_35
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_36
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_39
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_3
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_40
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_42
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_43
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_46
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_4
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_50
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_61
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_64
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_78
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_79
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_8
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_9
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_0
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_16
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_17
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_1
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_23
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_24
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_25
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_26
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_27
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_28
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_29
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_31
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_32
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_40
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_42
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_4
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_53
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_65
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_6
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_71
# Finished 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_88
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_10
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_12
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_16
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_17
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_18
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_20
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_21
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_22
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_23
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_24
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_26
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_27
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_28
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_29
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_2
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_30
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_31
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_33
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_34
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_35
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_36
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_37
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_39
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_40
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_53
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_58
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_64
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_68
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_6
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_72
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_77
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_78
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_7
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_80
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_82
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_87
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_9
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_0
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_12
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_13
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_15
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_16
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_17
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_19
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_1
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_20
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_21
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_23
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_24
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_26
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_27
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_28
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_29
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_2
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_32
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_33
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_35
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_37
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_38
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_42
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_4
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_51
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_5
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_66
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_7
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_0
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_11
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_12
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_13
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_14
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_15
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_16
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_17
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_18
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_19
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_20
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_22
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_23
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_25
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_26
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_28
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_29
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_2
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_31
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_34
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_35
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_36
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_37
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_38
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_39
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_3
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_40
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_42
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_43
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_47
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_4
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_50
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_52
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_5
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_61
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_64
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_68
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_69
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_6
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_70
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_71
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_72
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_73
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_77
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_79
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_81
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_90
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_92
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_94
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_96
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_97
# Finished 20231108_488EGFP-CAAX_10uMParaNitroBleb_3_cell_9
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_0
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_11
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_12
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_14
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_15
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_16
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_17
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_18
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_19
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_1
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_20
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_21
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_24
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_26
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_27
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_28
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_32
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_34
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_36
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_38
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_39
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_3
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_40
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_41
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_55
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_56
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_5
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_60
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_61
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_64
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_72
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_7
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_9
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_10
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_11
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_12
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_14
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_15
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_16
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_17
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_18
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_1
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_20
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_22
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_23
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_25
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_27
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_29
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_2
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_3
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_41
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_42
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_43
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_4
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_50
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_52
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_59
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_5
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_6
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_9
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_11
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_12
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_14
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_15
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_16
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_17
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_18
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_1
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_20
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_21
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_22
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_27
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_2
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_33
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_44
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_46
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_49
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_50
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_51
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_53
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_56
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_58
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_60
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_64
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_65
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_72
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_81
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_86
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_92
# Finished 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_9
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_1_cell_10
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_1_cell_14
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_1_cell_1
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_1_cell_20
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_1_cell_21
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_1_cell_23
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_1_cell_24
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_1_cell_27
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_1_cell_28
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_1_cell_33
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_1_cell_35
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_1_cell_3
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_1_cell_6
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_1_cell_7
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_1_cell_8
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_0
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_10
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_11
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_13
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_14
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_16
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_18
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_19
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_21
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_24
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_29
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_30
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_33
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_37
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_40
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_45
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_49
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_4
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_8
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_2_cell_9
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_0
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_10
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_12
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_13
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_15
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_25
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_26
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_27
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_28
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_2
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_30
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_31
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_34
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_3
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_42
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_4
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_51
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_52
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_5
# Finished 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_8

# %%
############## GET SURFACE MESHES AND OTHER SHAPE STATS ##############


savedir = 'D:/Aaron/Data/HL60 ParaNitroBlebbistatin/Processed_Data/'


#make dirs if it doesn't exist
datadir = 'D:/Aaron/Data/HL60 ParaNitroBlebbistatin/Data_and_Figs/'
if not os.path.exists(datadir):
    os.makedirs(datadir)
meshf = savedir+'Meshes/'  
if not os.path.exists(meshf):
    os.makedirs(meshf)
pilrf = savedir+'PILRs/'
if not os.path.exists(pilrf):
    os.makedirs(pilrf)

    
xyres = 0.3394 #um / pixel 
zstep = 0.7 # um
align_method = 'trajectory'
norm_rot = 'provided'
l_order = 10
nisos = [1,63]
sigma = 0
errorlist = []


if norm_rot == 'provided':
    widthpeaks = pd.read_csv(datadir + 'Closest_Width_Peaks.csv', index_col = 0)
    
#get all segmented images
imlist = [x for x in os.listdir(savedir) if x.endswith('segmented.tiff')]

start = 0
stop = 300
allresults = []
while start<len(imlist):
    print(f'Finished {start}, starting {start}-{stop}')
    if __name__ ==  '__main__':
        results = []
        pool = multiprocessing.Pool(processes=60)
        for i in imlist[start:stop]:
            #get path to segmented image
            impath = savedir + i
            
            #choose structure name based on file name
            if 'actin' in impath:
                str_name = 'actin'
            elif ('Hoechst' in impath) or ('DNA' in impath):
                str_name = 'nucleus'
            elif 'myosin' in impath:
                str_name = 'myosin'
            else:
                str_name = ''
            
            #assign the normal rotation value for that particular cell
            if (norm_rot == 'provided') or (type(norm_rot) == float):
                norm_rot = float(widthpeaks[widthpeaks.cell == i.split('_segment')[0]]['Closest_minimums'].values[0])
                
            #put in the pool
            pool.apply_async(shparam_mod.shcoeffs_and_PILR_nonuc, args = (
                impath,
                savedir,
                xyres,
                zstep,
                str_name,
                errorlist,
                norm_rot,
                l_order,
                nisos,
                sigma,
                align_method,
                ),             
                callback = collect_results)

        pool.close()
        pool.join()
    
    allresults.extend(results)
    
    start = stop + 1
    stop = stop + 1000
    if stop>len(imlist):
        stop = len(imlist)

errorlist = []
bigdf = pd.DataFrame()

for r in allresults:
    

    Shape_Stats = pd.DataFrame([r[0].values()],
                                  columns = list(r[0].keys()))
    cell_coeffs = pd.DataFrame([r[1].values()],
                               columns = list(r[1].keys()))

    bigdf = bigdf.append(pd.concat([Shape_Stats,cell_coeffs], axis=1))

    errorlist.extend(r[2])


#save the shape metrics dataframe
bigdf = bigdf.set_index('cell')
bigdf.to_csv(datadir + 'Shape_Metrics.csv')

#save list of cells that don't have centroid in shape
pd.Series(errorlist).to_csv(datadir + 'ListToExclude.csv')
# Out:
# Finished 0, starting 0-300
# Finished 301, starting 301-1300
# Finished 1301, starting 1301-2300
# Finished 2301, starting 2301-3300
# Finished 3301, starting 3301-4300
# Finished 4301, starting 4301-5300
# Finished 5301, starting 5301-6300
# Finished 6301, starting 6301-7300
# Finished 7301, starting 7301-8300
# Finished 8301, starting 8301-9300
# Finished 9301, starting 9301-10300
# Finished 10301, starting 10301-11300
# Finished 11301, starting 11301-12300
# Finished 12301, starting 12301-13300
# Finished 13301, starting 13301-14300
# Finished 14301, starting 14301-15300
# Finished 15301, starting 15301-16300
# Finished 16301, starting 16301-17300
# Finished 17301, starting 17301-18300
# Finished 18301, starting 18301-19300
# Finished 19301, starting 19301-20300
# Finished 20301, starting 20301-21300
# Finished 21301, starting 21301-22300
# Finished 22301, starting 22301-23300
# Finished 23301, starting 23301-24300
# Finished 24301, starting 24301-25300
# Finished 25301, starting 25301-26300
# Finished 26301, starting 26301-27300
# Finished 27301, starting 27301-28300
# Finished 28301, starting 28301-29300
# Finished 29301, starting 29301-30300
# Finished 30301, starting 30301-31300
# Finished 31301, starting 31301-32300
# Finished 32301, starting 32301-33300
# Finished 33301, starting 33301-34300
# Finished 34301, starting 34301-35300
# Finished 35301, starting 35301-35819

# %%
#################### Check shape distributions for extreme outliers before PCA ####################
import matplotlib.pyplot as plt
folder_fl = 'D:/Aaron/Data/HL60 ParaNitroBlebbistatin/'
data_fl = folder_fl + 'Data_and_Figs/'
info_fl = folder_fl + 'Processed_Data/'

#open full dataframe
df = pd.read_csv(data_fl + 'Shape_Metrics.csv', index_col='cell')


excludes = pd.read_csv(data_fl + 'ListToExclude.csv', index_col=0)
exlist = [i.replace('_segmented.tiff', '') for i in excludes.iloc[:,0].to_list()]
df = df.loc[[x for x in df.index if x not in exlist]]

#add all of the other metrics from the single csv files
cellinfo = pd.DataFrame()
for i in df.index.to_list():
    tc = pd.read_csv(info_fl + i +'_cell_info.csv', index_col = 0)
    cellinfo = cellinfo.append(tc.loc[0])
# Add distance travelled per framerate to total frame
cellinfo.index = cellinfo.cell
df = df.merge(cellinfo.drop(columns=['image', 'cropx (pixels)',
       'cropy (pixels)', 'cropz (pixels)']), left_index = True, right_index = True)

metrics = df.std().sort_values(ascending = False).index[:7]
# df = df[(df.Cell_Volume < 2070) & (df.Cell_Volume > 498)]
# df = df[df.Cell_SurfaceArea < 1800]
fig, axes = plt.subplots(len(metrics), 1, figsize=(25,20))#, sharex=True)
for i, ax in enumerate(axes):
    ax.hist(abs(df[metrics[i]]), 100) #, 30, (-2,2))
    ax.set_ylabel(metrics[i], fontsize = 13)
# #volume threshold determined by looking through cropped cell images
newdf = df[(df.Cell_Volume < 2070) & (df.Cell_Volume > 498)].copy()
newdf = newdf[(newdf.Cell_SurfaceArea < 1800) & (newdf.Cell_SurfaceArea > 500)]

newdf.to_csv(data_fl + 'Shape_Metrics_outliersremoved.csv')
# Out:
# C:\Users\Aaron\anaconda3\envs\abhishape\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
ratios = (newdf.Cell_MajorAxis/df.Cell_MinorAxis)-1
ratios[ratios<0].sort_values()#[-40:]
# df.Cell_MajorAxis
# df = pd.read_csv(data_fl + 'Shape_Metrics.csv', index_col='cell')
# df[df.index =='20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_30_frame_148'].iloc[0].to_dict()#[['Cell_MajorAxis','Cell_MinorAxis']]

# impath = savedir+'20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_30_frame_148_segmented.tiff'
# shparam_mod.shcoeffs_and_PILR_nonuc(
#                 impath,
#                 savedir,
#                 xyres,
#                 zstep,
#                 str_name,
#                 errorlist,
#                 norm_rot,
#                 l_order,
#                 nisos,
#                 sigma,
#                 align_method,
#                 )

# folder_fl = 'D:/Aaron/Data/HL60 ParaNitroBlebbistatin/'
# data_fl = folder_fl + 'Data_and_Figs/'
# info_fl = folder_fl + 'Processed_Data/'

# #open full dataframe
# df = pd.read_csv(data_fl + 'Shape_Metrics.csv', index_col='cell')
# realmajor = df.Cell_MiniAxis.copy()
# realmini = df.Cell_MajorAxis.copy()
# df['Cell_MajorAxis'] = realmajor
# df['Cell_MiniAxis'] = realmini
# df.to_csv(data_fl + 'Shape_Metrics.csv')
# Out:
# cell
# 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_34_frame_9        -0.240250
# 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_42_frame_174   -0.211274
# 20231108_488EGFP-CAAX_0.1percentDMSO_4_cell_42_frame_153      -0.210373
# 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_20_frame_59       -0.196893
# 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_53_frame_157      -0.191224
#                                                                  ...
# 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_35_frame_52    -0.000318
# 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_14_frame_112      -0.000232
# 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_20_frame_6        -0.000174
# 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_34_frame_171   -0.000145
# 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_9_frame_28        -0.000039
# Length: 524, dtype: float64

# %%
ratios = (realmini/df.Cell_MinorAxis) - 1
ratios[ratios<0]
# Out:
# cell
# 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_10_frame_39     -0.196385
# 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_10_frame_31     -0.479771
# 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_10_frame_3      -0.146219
# 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_10_frame_58     -0.242212
# 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_10_frame_2      -0.328821
#                                                                ...
# 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_8_frame_99   -0.288595
# 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_8_frame_96   -0.344325
# 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_8_frame_97   -0.307889
# 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_8_frame_9    -0.497901
# 20231113_488EGFP-CAAX_10uMParaNitroBleb_3_cell_8_frame_92   -0.382651
# Length: 33113, dtype: float64

# %%
df.Cell_Volume.sort_values(ascending=False).head(1000)
# df.Cell_Volume.std()*3.5
# Out:
# cell
# 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_24_frame_21     81712.682720
# 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_46_frame_59        35487.683163
# 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_72_frame_173       30132.416820
# 20231113_488EGFP-CAAX_0.1percentDMSO_2_cell_20_frame_145       28521.494460
# 20231113_488EGFP-CAAX_0.1percentDMSO_3_cell_14_frame_4         27664.096088
#                                                                    ...
# 20231108_488EGFP-CAAX_0.1percentDMSO_1_cell_53_frame_121        2080.945176
# 20231108_488EGFP-CAAX_10uMParaNitroBleb_1_cell_80_frame_169     2079.500477
# 20231113_488EGFP-CAAX_0.1percentDMSO_1_cell_5_frame_49          2079.319058
# 20231108_488EGFP-CAAX_0.1percentDMSO_2_cell_19_frame_71         2078.200248
# 20231108_488EGFP-CAAX_10uMParaNitroBleb_2_cell_66_frame_137     2077.293107
# Name: Cell_Volume, Length: 1000, dtype: float64

# %%
######### Perform PCA and divide cells into shape space bins ################

#import stuff and define functions
from typing import Dict, List, Optional, Union
from pathlib import Path
from sklearn.decomposition import IncrementalPCA, PCA
from CustomFunctions import shapePCAtools
import math
from vtk.util import numpy_support
import vtk
from aicsshparam import shtools
import pickle as pk

folder_fl = 'D:/Aaron/Data/CK666/'
data_fl = folder_fl + 'Data_and_Figs/'


#specify number of PCs and number of bins
npcs = 10
nbins = 5
bins = list(range(1,nbins+1))
lmax = 10

#open full dataframe
df = pd.read_csv(data_fl + 'Shape_Metrics_outliersremoved.csv', index_col='cell')


#exclude cells with centroids outside the mesh
excludes = pd.read_csv(data_fl + 'ListToExclude.csv', index_col=0)
exlist = [i.replace('_segmented.tiff', '') for i in excludes.iloc[:,0].to_list()]
df = df.loc[[x for x in df.index if x not in exlist]]
coeff_df = df[[x for x in df.columns.to_list() if 'shcoeffs' in x]]



# Fit and transform the data
pca = PCA(n_components=npcs)
pca = pca.fit(coeff_df)
matrix_of_features_transform = pca.transform(coeff_df)
coeff_df
# Out:
#                                                     shcoeffs_L0M0C  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...       16.300343
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...       15.649429
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...       15.645974
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...       16.260471
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...       15.777082
# ...                                                            ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92        13.407781
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9         15.703535
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95        11.939461
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96        11.927563
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94        12.264535
#
#                                                     shcoeffs_L0M1C  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# ...                                                            ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9               0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94              0.0
#
#                                                     shcoeffs_L0M2C  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# ...                                                            ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9               0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94              0.0
#
#                                                     shcoeffs_L0M3C  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# ...                                                            ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9               0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94              0.0
#
#                                                     shcoeffs_L0M4C  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# ...                                                            ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9               0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94              0.0
#
#                                                     shcoeffs_L0M5C  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# ...                                                            ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9               0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94              0.0
#
#                                                     shcoeffs_L0M6C  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# ...                                                            ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9               0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94              0.0
#
#                                                     shcoeffs_L0M7C  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# ...                                                            ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9               0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94              0.0
#
#                                                     shcoeffs_L0M8C  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0
# ...                                                            ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9               0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96              0.0
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94              0.0
#
#                                                     shcoeffs_L0M9C  ...  \
# cell                                                                ...
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0  ...
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0  ...
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0  ...
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0  ...
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...             0.0  ...
# ...                                                            ...  ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92              0.0  ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9               0.0  ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95              0.0  ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96              0.0  ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94              0.0  ...
#
#                                                     shcoeffs_L10M1S  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.139449
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.044975
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.031418
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.107194
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.085244
# ...                                                             ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92         -0.010394
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9           0.072615
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95          0.111605
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96          0.148313
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94          0.007725
#
#                                                     shcoeffs_L10M2S  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.005973
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.061557
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.116526
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.055459
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.105998
# ...                                                             ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92          0.009837
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9           0.135334
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95          0.035935
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96         -0.168436
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94         -0.186675
#
#                                                     shcoeffs_L10M3S  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.093485
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.044416
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.040377
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.101472
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.181098
# ...                                                             ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92          0.061180
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9           0.077322
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95         -0.247569
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96         -0.088652
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94         -0.116732
#
#                                                     shcoeffs_L10M4S  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.028145
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.045690
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.110219
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.053186
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.061116
# ...                                                             ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92          0.093085
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9          -0.045931
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95          0.144003
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96          0.184499
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94          0.201985
#
#                                                     shcoeffs_L10M5S  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.014014
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.042238
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.189908
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.042964
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.007576
# ...                                                             ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92         -0.139658
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9           0.050452
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95          0.080707
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96          0.108395
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94          0.151731
#
#                                                     shcoeffs_L10M6S  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.013251
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.009385
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.139334
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.096229
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.105172
# ...                                                             ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92         -0.138449
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9           0.082386
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95         -0.120669
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96         -0.262718
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94         -0.205061
#
#                                                     shcoeffs_L10M7S  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.053699
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.020068
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.024246
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.016914
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.036130
# ...                                                             ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92          0.062300
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9           0.022089
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95          0.050247
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96         -0.145504
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94          0.040668
#
#                                                     shcoeffs_L10M8S  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.056791
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.120599
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.071840
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.248399
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.000877
# ...                                                             ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92          0.033020
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9          -0.022840
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95          0.202564
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96          0.105317
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94          0.005625
#
#                                                     shcoeffs_L10M9S  \
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.141338
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.071174
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.219317
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         0.004703
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...        -0.002777
# ...                                                             ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92          0.187983
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9          -0.043985
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95         -0.304795
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96          0.078072
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94         -0.015247
#
#                                                     shcoeffs_L10M10S
# cell
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...          0.014171
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         -0.132963
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         -0.242287
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...          0.109843
# 20231031_488EGFP-CAAX_0.1percentDMSO_1_cell_0_f...         -0.086295
# ...                                                              ...
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_92          -0.113245
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_9            0.024579
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_95           0.001632
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_96          -0.134757
# 20231031_488EGFP-CAAX_10uMCK666_3_cell_9_frame_94          -0.264943
#
# [9064 rows x 242 columns]

# %%
matrix_of_features_transform[:,1].max()
# Out:
# 7.437813721092662

# %%
######### Perform PCA and divide cells into shape space bins ################

#import stuff and define functions
from typing import Dict, List, Optional, Union
from pathlib import Path
from sklearn.decomposition import IncrementalPCA, PCA
from CustomFunctions import shapePCAtools
import math
from vtk.util import numpy_support
import vtk
from aicsshparam import shtools
import pickle as pk

folder_fl = 'D:/Aaron/Data/CK666/'
data_fl = folder_fl + 'Data_and_Figs/'


#specify number of PCs and number of bins
npcs = 10
nbins = 5
bins = list(range(1,nbins+1))
lmax = 10

#open full dataframe
df = pd.read_csv(data_fl + 'Shape_Metrics_outliersremoved.csv', index_col='cell')


#exclude cells with centroids outside the mesh
excludes = pd.read_csv(data_fl + 'ListToExclude.csv', index_col=0)
exlist = [i.replace('_segmented.tiff', '') for i in excludes.iloc[:,0].to_list()]
df = df.loc[[x for x in df.index if x not in exlist]]
coeff_df = df[[x for x in df.columns.to_list() if 'shcoeffs' in x]]



# Fit and transform the data
pca = PCA(n_components=npcs)
pca = pca.fit(coeff_df)
matrix_of_features_transform = pca.transform(coeff_df)


# Dataframe of transformed variable
pc_names = [f"Cell_PC{c}" for c in range(1, 1 + npcs)]
df_trans = pd.DataFrame(data=matrix_of_features_transform, columns=pc_names, index = coeff_df.index)


# Adjust the sign of PCs so that larger cells are represent by positive values
#need actual volume data to do this so needs to be combined with shape metrics
df_trans['Cell_Volume'] = df.Cell_Volume
for pcid, pc_name in enumerate(pc_names):
    pearson = np.corrcoef(df_trans.Cell_Volume.values, df_trans[pc_name].values)
    if pearson[0, 1] < 0:
        df_trans[pc_name] *= -1
        pca.components_[pcid] *= -1

df_trans = df_trans.drop(columns = 'Cell_Volume')



################ RECONSTRUCT CELLS AT CERTAIN POINTS IN THE "SHAPE SPACE" ##################

df_dig = pd.DataFrame(index = df_trans.index)
for count, col in enumerate(df_trans.columns.to_list()):
    df_digit, bin_indexes, (bin_centers, pc_std) = shapePCAtools.digitize_shape_mode(
        df = df_trans,
        feature = col,
        nbins = nbins,
        filter_based_on = df_trans.columns.to_list(),
        filter_extremes_pct = float(1),
        save = None,
        return_freqs_per_structs = False
    )
    #put bin_indexes into a larger list that I can later iterate through
    df_dig = df_dig.merge(df_digit[[col,'bin']], left_index = True, right_index = True)
    df_dig = df_dig.rename(columns={'bin':f'PC{count+1}_bins'})

    
mid = math.ceil(nbins/2)
recon_PCs = np.zeros((npcs, nbins, npcs))
for pi, p in enumerate(pc_names):
    for c in range(nbins):
        for ni, n in enumerate(pc_names):
            if n == p:
                recon_PCs[pi,c,ni] = df_dig[df_dig[f'PC{ni+1}_bins']==c+1].loc[:,n].mean()
            else:
                recon_PCs[pi,c,ni] = df_dig[df_dig[f'PC{ni+1}_bins']==mid].loc[:,n].mean()

#get inverse pca transform of those values
recon_schoeffs = np.zeros((npcs, nbins, len(coeff_df.columns)))
for o in range(recon_schoeffs.shape[0]):
    for t in range(recon_schoeffs.shape[1]):
            recon_schoeffs[o,t,:] = pca.inverse_transform(recon_PCs[o,t,:])
            
    
#combine metrics and digitized pcs
df_dig = df.merge(df_dig, left_index = True, right_index = True)
#save
df_dig.to_csv(data_fl+"Shape_Metrics_with_Digitized_PCs.csv")


########### GET RECONSTRUCTIONS OF AVERAGE CELLS FROM SHAPE SPACE BINS ##########################

meshes = {}
aliases = ['Cell']

for pi, p in enumerate(pc_names):
    meshes[p] = {}
    for c in range(nbins):
        meshes[p][bins[c]] = {}
        row = pd.Series(recon_schoeffs[pi,c,:], index = coeff_df.columns.to_list())
        for i, a in enumerate(aliases):
            mesh, _ = shtools.get_reconstruction_from_coeffs(recon_schoeffs[pi,c,:].reshape(2,lmax+1,lmax+1))
            meshes[p][bins[c]][a] = mesh

                
                
################## save PC meshes ##################
savedir = folder_fl + 'PC_Meshes/'
if not os.path.exists(savedir):
    os.makedirs(savedir)
for p in list(meshes):
    for n, b in enumerate(list(meshes[p])):
        for a in list(meshes[p][b]):
            writer = vtk.vtkXMLPolyDataWriter()
            writer.SetFileName(savedir+p+'_'+str(b)+'_'+a+'.vtp')
            writer.SetInputData(meshes[p][b][a])
            writer.Write()

####### also save the pca object for later use ###########
pk.dump(pca, open(data_fl+"pca.pkl","wb"))

# %%
folder_fl = 'D:/Aaron/Data/CK666/'
data_fl = folder_fl + 'Data_and_Figs/'

########### plot distributions of PCs ###################
import matplotlib.pyplot as plt
fig, axes = plt.subplots(10, 1, figsize=(6,12), sharex=True)
for i, ax in enumerate(axes[:]):
    ax.hist(df_trans.iloc[:,i].values, 30)
# for i, ax in enumerate(axes[:,1]):
#     ax.hist(nuc_weights[:,i], 30, (-2,2))
    
axes[0].set_title("PC Distributions", fontsize = 20)
# axes[0,1].set_title("Nucleus Distributions", fontsize = 20)
[ax.set_ylabel("PC %i"%(i+1), fontsize = 16) for i, ax in enumerate(axes[:])];
axes[7].set_xlabel("Component value")

plt.tight_layout()
plt.savefig(data_fl+ 'PC distributions.png', bbox_inches='tight')



# How much variance is explained?
cell_variance = np.cumsum(pca.explained_variance_ratio_)
component_number = np.arange(len(cell_variance)) + 1

# Analysis of explained variance
df_dimred = {}
loading = pca.components_.T * np.sqrt(pca.explained_variance_)
for comp, pc_name in enumerate(pc_names):
    load = loading[:, comp]
    pc = [v for v in load]
    apc = [v for v in np.abs(load)]
    total = np.sum(apc)
    cpc = [100 * v / total for v in apc]
    df_dimred[pc_name] = pc
    df_dimred[pc_name.replace("_PC", "_aPC")] = apc
    df_dimred[pc_name.replace("_PC", "_cPC")] = cpc

# Store results as a dataframe
df_dimred["features"] = coeff_df.columns
df_dimred = pd.DataFrame(df_dimred)
df_dimred = df_dimred.set_index("features", drop=True)

# Plot variance
plt.figure(figsize=(4, 3))
plt.plot(component_number, cell_variance)
plt.ylim(0,1)
plt.xlabel("n-components")
plt.ylabel("Explained variance")
plt.title("Fraction of variance captured")

plt.tight_layout()
plt.savefig(data_fl + 'Variance captured.png', bbox_inches='tight')



# ######## OR A DIFFERENT PLOT ##############
# # Make plot of explained variance
# plt.plot(100 * pca.explained_variance_ratio_[:npcs_to_calc], "-o")
# title = "Cum. variance: (1+2) = {0}%, Total = {1}%".format(
#     int(100 * pca.explained_variance_ratio_[:2].sum()),
#     int(100 * pca.explained_variance_ratio_[:].sum()),
# )
# plt.xlabel("Component", fontsize=18)
# plt.ylabel("Explained variance (%)", fontsize=18)
# plt.xticks(
#     ticks=np.arange(npcs_to_calc),
#     labels=np.arange(1, 1 + npcs_to_calc),
#     fontsize=14,
# )
# plt.yticks(fontsize=14)
# plt.title(title, fontsize=18)
# plt.tight_layout()



############## SEE WHICH FEATURES ARE MOST IMPORTANT IN EACH PC #############
save = data_fl + 'Feature_Importance'
# Log feature importance along each PC
with open(f"{save}.txt", "w") as flog:

    for comp in range(npcs):

        print(
            f"\nExamplined variance by PC{comp+1} = {100*pca.explained_variance_ratio_[comp]:.1f}%",
            file=flog,
        )

        # Feature importance is reported in 3 ways:
        # _PC - raw loading
        # _aPC - absolute loading
        # _cPC - normalized cummulative loading
        pc_name = pc_names[comp]
        df_sorted = df_dimred.sort_values(
            by=[pc_name.replace("_PC", "_aPC")], ascending=False
        )
        pca_cum_contrib = np.cumsum(
            df_sorted[pc_name.replace("_PC", "_aPC")].values
            / df_sorted[pc_name.replace("_PC", "_aPC")].sum()
        )
        pca_cum_thresh = np.abs(pca_cum_contrib - 0.80).argmin()
        df_sorted = df_sorted.head(n=pca_cum_thresh + 1)

        print(
            df_sorted[
                [
                    pc_name,
                    pc_name.replace("_PC", "_aPC"),
                    pc_name.replace("_PC", "_cPC"),
                ]
            ].head(),
            file=flog,
        )
